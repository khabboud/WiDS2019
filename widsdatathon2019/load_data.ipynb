# %%
import sys, os
sys.path.insert(0, '../')
from oilpalm import OilPalmImages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


train_file_directory = "train_images/"
labels_file_name = 'traininglabels.csv'
label_selection_probability = 0.5
label_selection_method = 'soft' #'hard'
reduced_image_height = 200
max_samples_class0 = 2000
max_samples_class1 = 1003
op_instance = OilPalmImages(file_directory= train_file_directory, labels_file_name = labels_file_name, 
                            pca_components= reduced_image_height, label_selection_probability = label_selection_probability, 
                            label_selection_method = label_selection_method,  max_samples_class0 = max_samples_class0,
                            max_samples_class1 =max_samples_class1)
op_instance.get_labels_from_file()
op_instance.read_train_images()
# Out:
# plot the distribution of the score value for each of the classes...
# plot the histogram of classes of the training samples...
# processing training sample#  0 from class 0.0
# processing training sample#  1 from class 0.0
# processing training sample#  2 from class 0.0
# processing training sample#  3 from class 0.0
# processing training sample#  4 from class 0.0
# processing training sample#  5 from class 0.0
# processing training sample#  6 from class 1.0
# processing training sample#  7 from class 0.0
# processing training sample#  8 from class 1.0
# processing training sample#  9 from class 0.0
# processing training sample#  10 from class 0.0
# processing training sample#  11 from class 0.0
# processing training sample#  12 from class 0.0
# processing training sample#  13 from class 0.0
# processing training sample#  14 from class 0.0
# processing training sample#  15 from class 0.0
# processing training sample#  16 from class 0.0
# ...

# %%
print(op_instance.X_train.shape)
plt.hist(op_instance.Y_train)
plt.show()
len(op_instance.Y_train[np.where(op_instance.Y_train==1)])

# Y_balance = op_instance.Y_train[np.where(op_instance.Y_train==1)]
# Y_balance_2 = op_instance.Y_train[np.where(op_instance.Y_train==0)[0][0:1003]]
# X_balance = op_instance.X_train[np.where(op_instance.Y_train==1)]
# X_balance_2 = op_instance.X_train[np.where(op_instance.Y_train==0)[0][0:1003]]

# y_train_balance = np.concatenate([Y_balance,Y_balance_2])
# x_train_balance = np.concatenate([X_balance,X_balance_2])
# plt.hist(y_train_balance )
# Out:
# (5003, 25600)
# 1003

# %%
from sklearn.model_selection import train_test_split
# from sklearn.utils import class_weight
# class_weights = class_weight.compute_class_weight('balanced',
#                                                  np.unique(op_instance.Y_train),
#                                                  op_instance.Y_train)
X_train, X_test, y_train, y_test = train_test_split(op_instance.X_train,op_instance.Y_train,train_size = 0.75, test_size = 0.25 , random_state=1)
#X_train, X_test, y_train, y_test = train_test_split(x_train_balance,y_train_balance,train_size = 0.75, test_size = 0.25 , random_state=1)

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5,2), random_state=1)
clf.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=1e-05, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(5, 2), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
# from sklearn.linear_model import LogisticRegression
# LR_Model= LogisticRegression(class_weight=class_weights)

# LR_Model.fit(op_instance.X_train,op_instance.Y_train)
# LR_test_score =LR_Model.score(X_test, y_test)
# print ("Logistic regression test score= {}".format(LR_test_score))

# %%
test_res = pd.DataFrame()
test_res['image_id'] = ['id','2']
test_res.to_csv('out.csv')
test_res.head(100)
# Out:
#   image_id
# 0       id
# 1        2

# %%
clf.predict(X_test[0,:].reshape(1, -1))[0]
# Out:
# 1.0

# %%
t = clf.predict_proba(X_test)
y_pred = clf.predict(X_test)
print("Logistic regression test score=",clf.score(X_test,y_test))
plt.hist(y_pred)
plt.show()


print(" minimum prediction probability for class 0  ", min(t[:,0]))
print(" max prediction probability for class 0  ", max(t[:,0]))
print(" minimum probability for class 1 ",min(t[:,1]))
print(" max prediction probability for class 1 ", max(t[:,1]))

# y =  [0 if x>0.616 else 1 for x in t[:,0]]
# print(y)
# plt.hist(y)
# plt.show()
# print(y-y_test)
# Out:
# Logistic regression test score= 0.592326139088729
#  minimum prediction probability for class 0   0.36854431552418876
#  max prediction probability for class 0   1.0
#  minimum probability for class 1  4.877092307790467e-195
#  max prediction probability for class 1  0.6314556844758112

# %%
# Compute confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print(cm)

# Show confusion matrix in a separate window
plt.matshow(cm)
plt.title('Confusion matrix')
plt.colorbar()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# [[638 368]
#  [142 103]]

# %%
from PIL import Image
import matplotlib.image as mpimg
import sys, os
import matplotlib.pyplot as plt
import numpy as np
sys.path.insert(0, '../')
img_file = 'img_110002018.jpg'
# copied some images (less) to another folder (train_images_less) to try stuff on less number of images first 
file_directory = "train_images_less/"
im = Image.open(file_directory+img_file, 'r')
img=mpimg.imread(file_directory+img_file)
pix_val = list(im.getdata())
width, height = im.size
print(width)
print(height)
print(im.getbands())

pix_val_flat = np.asarray([x for sets in pix_val for x in sets])
pix_R_val_flat = np.asarray([sets[0] for sets in pix_val])
pix_G_val_flat = np.asarray([sets[1] for sets in pix_val])
pix_B_val_flat = np.asarray([sets[2] for sets in pix_val])
print(len(pix_val_flat))
256*256*3
plt.imshow(img)
plt.show()
print(img.shape)
# pix_RG = np.asarray()
# print(list(pix_R_val_flat).append(list(pix_G_val_flat)))
img_R = np.asarray(pix_R_val_flat.reshape(([width,height])))
plt.imshow(img_R)
plt.show()
img_G = np.asarray(pix_G_val_flat.reshape(([width,height])))
plt.imshow(img_G)
plt.show()
img_RG = np.asarray(np.concatenate((img_R,img_G),axis=0))
print(img_RG.shape)
plt.imshow(img_RG)
plt.show()
img_B = np.asarray(pix_B_val_flat.reshape(([width,height])))
plt.imshow(img_B)
plt.show()
img_2 = np.asarray(pix_val_flat.reshape(([width,height,3])))
print(img_2.shape)
plt.imshow(img_2)
plt.show()
# Out:
# 256
# 256
# ('R', 'G', 'B')
# 196608
# (256, 256, 3)
# (512, 256)
# (256, 256, 3)

# %%
# from ipywidgets import interact, interactive, fixed, interact_manual
# import ipywidgets as widgets
# interact(compress_RGBimg, k =(1,300));

# %%
# compressing images
# source: https://medium.com/@rameshputalapattu/jupyter-python-image-compression-and-svd-an-interactive-exploration-703c953e44f6


from numpy.linalg import svd
def compress_RGBimg(img = img_2, k = 4):
    original_shape = img.shape
    img_reshaped = img.reshape((original_shape[0],original_shape[1]*3))
    img_reconst_mat,_ = compress_svd(img_reshaped, k)
    img_reconst = img_reconst_mat.reshape(original_shape)
    compression_ratio = 100.0*(k*(original_shape[0]+ 3*original_shape[1])+k)/(original_shape[0]*original_shape[1]*original_shape[2])
    plt.title("compression ratio={:.2f}".format(compression_ratio)+"%")
    # RGB pixel values need to be int (0,255)
    plt.imshow(img_reconst.astype(int))
    return img_reconst, img_reconst_mat
    
def compress_svd(img,k):
    U,s,V = svd(img, full_matrices = False)
    reconst_mat = np.dot(U[:,:k],np.dot(np.diag(s[:k]), V[:k,:]))
    return reconst_mat, s

# %%
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# -0.5007078890677884
# 301.00690706744126
# 0.0
# 255.0
# (256, 768)

# %%
path, dirs, files = next(os.walk(file_directory))
file_count = len(files)

# %%
X_R = - np.ones([file_count,width*height])
X_G = - np.ones([file_count,width*height])
X_B = - np.ones([file_count,width*height])
X = - np.ones([file_count,3*width*height])

# %%
from os import listdir
f_count = 0
for f in listdir(file_directory):
    print("processing image#",f_count)
    file_loc = ''.join([file_directory, f])
    im = Image.open(file_directory+f, 'r')
    pix_val = list(im.getdata())
    width_f, height_f = im.size
    assert width_f==width,  "ERROR width not equal to rest of images"
    assert height_f==height,  "ERROR height not equal to rest of images"    
    X[f_count,:] = [x for sets in pix_val for x in sets]
    X_R[f_count,:] = [sets[0] for sets in pix_val]
    X_G[f_count,:] = [sets[1] for sets in pix_val]
    X_B[f_count,:] = [sets[2] for sets in pix_val]
    f_count +=1
# Out:
# processing image# 0
# processing image# 1
# processing image# 2
# processing image# 3
# processing image# 4
# processing image# 5
# processing image# 6
# processing image# 7
# processing image# 8
# processing image# 9
# processing image# 10
# processing image# 11
# processing image# 12
# processing image# 13
# processing image# 14
# processing image# 15
# processing image# 16
# processing image# 17
# processing image# 18
# processing image# 19
# processing image# 20
# processing image# 21
# processing image# 22
# processing image# 23
# processing image# 24
# processing image# 25
# processing image# 26
# processing image# 27
# processing image# 28
# processing image# 29
# processing image# 30
# processing image# 31
# processing image# 32
# processing image# 33
# processing image# 34
# processing image# 35
# processing image# 36
# processing image# 37
# processing image# 38
# processing image# 39
# processing image# 40
# processing image# 41
# processing image# 42
# ...

# %%
#try compressing an image and see how it looks like
k = 6 
comp_img, comp_img_mat= compress_RGBimg(img_2, k)
print(np.min(comp_img))
print(np.max(comp_img))
print(np.min(X[0,:]))
print(np.max(X[0,:]))
plt.show()

#not sure that's helping when i still have the same size :S mmm
comp_img_mat.shape
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# -0.5007078890677884
# 301.00690706744126
# 0.0
# 255.0
# (256, 768)

# %%
# I can apply PCA on the training data set (but that's a huge matrix),
from sklearn.decomposition import PCA
def apply_PCA(X):
    pca_dims = PCA()
    pca_dims.fit(x)
    cumsum = np.cumsum(pca_dims.explained_variance_ratio_)
    d = np.argmax(cumsum >= 0.95) + 1
    print('reduced dimension of the training data X after PCA=',d)

# %%
# I want to reduce the size of each image first before constucting the training matrix 
# does applying PCA on each image alone makes sense? 
def apply_PCA_onImage(img, num_components = None, var = 0.95):
    original_shape = img.shape
    X = img.reshape((original_shape[0],original_shape[1]*3))
    if num_components is None: 
        pca = PCA(var)
    else:
        pca = PCA(n_components = num_components)
    img_reduced_mat = pca.fit_transform(X)
    print('original dimension of the img', X.shape )
    print('reduced dimension of the img after PCA=',img_reduced_mat.shape)
    img_reconst_mat= pca.inverse_transform(img_reduced_mat)
    img_reconst = img_reconst_mat.reshape(original_shape)
    print("-----image reconstructed from PCA reduced representation----")
    # RGB pixel values need to be int (0,255)
    plt.imshow(img_reconst.astype(int))
    return img_reconst, img_reduced_mat

# %%
img_reconst, img_reduced_mat = apply_PCA_onImage(img_2, var = 0.50)
img_reconst, img_reduced_mat = apply_PCA_onImage(img_2, num_components=60)
img_reduced_mat.shape
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# original dimension of the img (256, 768)
# reduced dimension of the img after PCA= (256, 2)
# -----image reconstructed from PCA reduced representation----
# original dimension of the img (256, 768)
# reduced dimension of the img after PCA= (256, 60)
# -----image reconstructed from PCA reduced representation----
# (256, 60)

# %%
# RGB pixel values need to be int (0,255)
plt.imshow(np.asarray(X[3,:].astype(int).reshape((width,height,3 ))))

# %%
import sys, os
sys.path.insert(0, '../')
from oilpalm import OilPalmImages
train_file_directory = "train_images_less/"

op_instance = OilPalmImages(file_directory= train_file_directory, pca_components= 30)
op_instance.read_train_images()
